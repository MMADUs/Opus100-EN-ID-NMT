# %%
# %load_ext autoreload
# %autoreload 2

from inference import translate
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch 
torch.__version__, torch.cuda.is_available()
# Out:
# ('2.9.1+cu130', True)

# %%
sentence = "im very tired, lets get some drinks"
translation = translate(sentence)
print(translation)
# Out:
# Aku sangat lelah , ayo kita minum .

# %%
sentence = "good morning, lets have a breakfast together"
translation = translate(sentence)
print(translation)
# Out:
# Selamat pagi , mari kita sarapan bersama

# %%
sentence = "good evening, see you tomorrow during work"
translation = translate(sentence)
print(translation)
# Out:
# Selamat malam , sampai besok bekerja

# %%
sentence = "hello my name is nizwa, i love playing football"
translation = translate(sentence)
print(translation)
# Out:
# Halo namaku , aku suka bermain sepak bola
