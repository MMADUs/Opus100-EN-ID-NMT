# %%
# %load_ext autoreload
# %autoreload 2

from inference import TranslationContext
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch

torch.__version__, torch.cuda.is_available()
# Out:
# ('2.9.1+cu130', True)

# %%
context = TranslationContext()

# %%
sentence = "im very tired, lets get some drinks, lets go to the nearest supermarket, i hope it does not cost much"
trnslation = context.translate(sentence)
print(trnslation)
# Out:
# Aku sangat lelah , memungkinkan minum , memungkinkan pergi ke supermarket terdekat , saya berharap itu tidak banyak biaya

# %%
sentence = "good morning, lets have a breakfast together, we are going to school this morning and dont forget to prepare"
translation = context.translate(sentence)
print(translation)
# Out:
# Selamat pagi , mari kita sarapan bersama , kita akan sekolah pagi ini dan tidak lupa untuk mempersiapkan diri

# %%
sentence = "good evening, see you tomorrow during work, i will bring some food for tomorrow so we can eat together during lunch"
translation = context.translate(sentence)
print(translation)
# Out:
# Selamat malam , sampai besok bekerja , aku akan membawa makanan untuk besok pagi jadi kita bisa makan bersama - sama selama makan siang .

# %%
sentence = "hello my name is nizwa, i love playing football, and i love playing games"
translation = context.translate(sentence)
print(translation)
# Out:
# Halo namaku , aku suka bermain sepak bola , dan aku suka bermain permainan .

# %%
sentence = "this model is built by the person called nizwa"
translation = context.translate(sentence)
print(translation + " nizwa")
# Out:
# Model ini dibuat oleh orang yang disebut nizwa
